# %% [markdown]
# ## Introduction
#
# Data visualization is the graphic representation of data. It involves producing images that communicate relationships among the represented data to viewers. Visualizing data is an essential part of data analysis and machine learning. We'll use Python libraries [Matplotlib](https://matplotlib.org) and [Seaborn](https://seaborn.pydata.org) to learn and apply some popular data visualization techniques. We'll use the words _chart_, _plot_, and _graph_ interchangeably in this tutorial.
#
# To begin, let's install and import the libraries. We'll use the `matplotlib.pyplot` module for basic plots like line & bar charts. It is often imported with the alias `plt`. We'll use the `seaborn` module for more advanced plots. It is commonly imported with the alias `sns`.

# %%
# %pip install matplotlib
# %pip install seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\python310\lib\site-packages (3.5.2)
# Requirement already satisfied: numpy>=1.17 in c:\python310\lib\site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\python310\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\python310\lib\site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: pandas>=0.23 in c:\python310\lib\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\python310\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: scipy>=1.0 in c:\python310\lib\site-packages (from seaborn) (1.9.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Notice this we also include the special command `%matplotlib inline` to ensure that our plots are shown and embedded within the Jupyter notebook itself. Without this command, sometimes plots may show up in pop-up windows.

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples);

# %% [markdown]
# ### Customizing the X-axis
#
# The X-axis of the plot currently shows list element indexes 0 to 5. The plot would be more informative if we could display the year for which we're plotting the data. We can do this by two arguments `plt.plot`.

# %%
years = range(2010,2016)
plt.plot(years,yield_apples);

# %%
plt.plot(yield_apples,years);

# %% [markdown]
# So, if we compare the above two results the plt.plot takes input in this fashion, `plt.plot(x_axis_data, y_axis_data)`

# %% [markdown]
# ### Axis Labels
#
# We can add labels to the axes to show what each axis represents using the `plt.xlabel` and `plt.ylabel` methods.

# %%
plt.plot(years,yield_apples)
plt.xlabel('Years')
plt.ylabel('Yield of apples');

# %% [markdown]
# ### Plotting Multiple Lines
#
# You can invoke the `plt.plot` function once for each line to plot multiple lines in the same graph. Let's compare the yields of apples vs. oranges in Kanto.

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years, apples)
plt.plot(years,oranges)
plt.xlabel('Years')
plt.ylabel('Yield(tons per hector)');

# %% [markdown]
# ### Chart Title and  Legend
#
# To differentiate between multiple lines, we can include a legend within the graph using the `plt.legend` function. We can also set a title for the chart using the `plt.title` function.

# %%
plt.plot(years, apples)
plt.plot(years, oranges)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title('Crop Yields in kanto')
plt.legend(['Apples','Oranges']);

# %% [markdown]
# ### Line Markers
#
# We can also show markers for the data points on each line using the `marker` argument of `plt.plot`. Matplotlib provides many different markers, like a circle, cross, square, diamond, etc. You can find the full list of marker types here: https://matplotlib.org/3.1.1/api/markers_api.html .

# %%
plt.plot(years, apples, marker='o')
plt.plot(years, oranges, marker='x')

plt.legend(['Apples','Oranges'])

plt.xlabel('Years')
plt.ylabel('Yield')

plt.title('Crop Yields in Kanto region');

# %% [markdown]
# ### Styling Lines and Markers
#
# The `plt.plot` function supports many arguments for styling lines and markers:
#
# - `color` or `c`: Set the color of the line ([supported colors](https://matplotlib.org/3.1.0/gallery/color/named_colors.html))
# - `linestyle` or `ls`: Choose between a solid or dashed line
# - `linewidth` or `lw`: Set the width of a line
# - `markersize` or `ms`: Set the size of markers
# - `markeredgecolor` or `mec`: Set the edge color for markers
# - `markeredgewidth` or `mew`: Set the edge width for markers
# - `markerfacecolor` or `mfc`: Set the fill color for markers
# - `alpha`: Opacity of the plot
#
#
# Check out the documentation for `plt.plot` to learn more: [https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) .

# %%
plt.plot(years, apples, marker='s', c='r', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(years, oranges, marker='o', c='b', ls='--', lw=3, ms=10, alpha=.5)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# let try the marker face colour

# %%
plt.plot(years, apples, marker='o', c='r', ls=':',alpha=0.5,mec='b')
plt.plot(years, oranges, marker='>', c='y', ls='--',lw=2, mec='b')

plt.xlabel('Years')
plt.ylabel('Yield')

plt.title('Crop yield in Kanto region')

plt.legend(['Apples','Oranges']);

# %% [markdown]
# ### Changing the Figure Size
#
# You can use the `plt.figure` function to change the size of the figure.

# %%
plt.figure(figsize=(12,8))

plt.plot(years, apples, marker='o', c='r', ls=':',alpha=0.5,mec='b')
plt.plot(years, oranges, marker='>', c='y', ls='--',lw=2, mec='b')

plt.xlabel('Years')
plt.ylabel('Yield')

plt.title('Crop yield in Kanto region')

plt.legend(['Apples','Oranges']);

# %% [markdown]
# The `fmt` argument provides a shorthand for specifying the marker shape, line style, and line color. It can be provided as the third argument to `plt.plot`.
#
# ```
# fmt = '[marker][line][color]'
# ```

# %% [markdown]
# ### Improving Default Styles using Seaborn
#
# An easy way to make your charts look beautiful is to use some default styles from the Seaborn library. These can be applied globally using the `sns.set_style` function. You can see a full list of predefined styles here: https://seaborn.pydata.org/generated/seaborn.set_style.html .

# %%
sns.set_style('whitegrid')

# %%
plt.figure(figsize=(12,8))

plt.plot(years, apples, marker='o', c='r', ls=':',alpha=0.5,mec='b')
plt.plot(years, oranges, marker='>', c='y', ls='--',lw=2, mec='b')

plt.xlabel('Years')
plt.ylabel('Yield')

plt.title('Crop yield in Kanto region')

plt.legend(['Apples','Oranges']);

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(12,8))

plt.plot(years,oranges,'s--')
plt.plot(years,apples,'o-r')

plt.xlabel('Year')
plt.ylabel('Yield')

plt.legend(['Oranges', 'Apples'])

plt.title('Crop yield in Kanto region');

# %% [markdown]
# ## Scatter Plot
#
# In a scatter plot, the values of 2 variables are plotted as points on a 2-dimensional grid. Additionally, you can also use a third variable to determine the size or color of the points. Let's try out an example.
#
# The [Iris flower dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set) provides sample measurements of sepals and petals for three species of flowers. The Iris dataset is included with the Seaborn library and can be loaded as a Pandas data frame.

# %%
flower_df = sns.load_dataset('iris')
type(flower_df)
# Out:
# pandas.core.frame.DataFrame

# %%
flower_df.head(4)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %% [markdown]
# Let's try to visualize the relationship between sepal length and sepal width. Our first instinct might be to create a line chart using `plt.plot`.

# %%
plt.figure(figsize=(10,8))

plt.plot(flower_df.sepal_length, flower_df.sepal_width);

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=flower_df.sepal_length, y=flower_df.sepal_width);

# %% [markdown]
# ##### hue & s
# hue- to add colors to data points
# s- to specify the size of data points

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=flower_df.sepal_length, y=flower_df.sepal_width, hue=flower_df.species, s=100);

# %%
plt.figure(figsize=(12,6))
plt.title("Sepal Dimensions")

sns.scatterplot(x=flower_df["sepal_length"], y=flower_df["sepal_width"], hue=flower_df["species"], s=80);

# %% [markdown]
# ### Plotting using Pandas Data Frames
#
# Seaborn has in-built support for Pandas data frames. Instead of passing each column as a series, you can provide column names and use the `data` argument to specify a data frame.

# %%
plt.figure(figsize=(12,8))
plt.title("Sepal Dimensions")

sns.scatterplot(x="sepal_length", y="sepal_width", hue="species", s=80, data=flower_df);

# %% [markdown]
# By providing `data`, we dont have to write the dataframe name everytime we have to specify the data.

# %% [markdown]
# ## Histogram
#
# A histogram represents the distribution of a variable by creating bins (interval) along the range of values and showing vertical bars to indicate the number of observations in each bin.
#
# For example, let's visualize the distribution of values of sepal width in the flowers dataset. We can use the `plt.hist` function to create a histogram.

# %%
flowers_df=sns.load_dataset("iris")

flowers_df["sepal_width"]
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df["sepal_width"]);

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.query('sepal_width >= 3.0 & sepal_width <= 3.5').sort_values(by=['sepal_width'])
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 61           5.9          3.0           4.2          1.5  versicolor
# 66           5.6          3.0           4.5          1.5  versicolor
# 75           6.6          3.0           4.4          1.4  versicolor
# 77           6.7          3.0           5.0          1.7  versicolor
# 84           5.4          3.0           4.5          1.5  versicolor
# ..           ...          ...           ...          ...         ...
# 27           5.2          3.5           1.5          0.2      setosa
# 43           5.0          3.5           1.6          0.6      setosa
# 40           5.0          3.5           1.3          0.3      setosa
# 36           5.5          3.5           1.3          0.2      setosa
# 0            5.1          3.5           1.4          0.2      setosa
#
# [74 rows x 5 columns]

# %% [markdown]
# Using `datafram.query()`

# %%
flowers_df.query('sepal_width >= 3.0 & sepal_width <= 3.4').shape[0]
# Out:
# 68

# %%
type(flowers_df.query('sepal_width >= 3.0 & sepal_width <= 3.4').count()), flowers_df.query('sepal_width >= 3.0 & sepal_width <= 3.4').count()
# Out:
# (pandas.core.series.Series,
#  sepal_length    68
#  sepal_width     68
#  petal_length    68
#  petal_width     68
#  species         68
#  dtype: int64)

# %%
sepal_count=flowers_df.query('sepal_width >= 3.0 & sepal_width <= 3.4').count()["sepal_width"]

# %%
type(sepal_count), sepal_count
# Out:
# (numpy.int64, 68)

# %% [markdown]
# ### Controlling the size and number of bins
#
# We can control the number of bins or the size of each one using the bins argument.

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df["sepal_width"]);

# %%
# Specifying the number of bins
plt.ylabel("Count")
plt.xlabel("Sepal Width")
plt.hist(flowers_df.sepal_width, bins=5);

# %%
# Specifying the boundaries of each bin
import numpy as np
plt.xlabel("Sepal Width")
plt.ylabel("Count")
plt.hist(flower_df["sepal_width"], bins=np.arange(2,5,0.25));

# %% [markdown]
# ### Multiple Histograms
#
# Similar to line charts, we can draw multiple histograms in a single chart. We can reduce each histogram's opacity  so that one histogram's bars don't hide the others'.
#
# Let's draw separate histograms for each species of flowers.

# %%
setosa = flower_df[flower_df["species"]=='setosa']
versicolor = flower_df[flower_df['species']=='versicolor']
virginica = flower_df[flower_df['species']=='virginica']

# %%
plt.title('Distribution of Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Count')
plt.hist([setosa['sepal_width'], versicolor['sepal_width'], virginica['sepal_width']], bins=np.arange(2,5,.5))
plt.legend(['setosa', 'versicolor', 'virginica']);

# %% [markdown]
# using `stacked` option.

# %%
plt.figure(figsize=(12,6))
plt.title('Distribution of Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Count')
plt.hist([setosa['sepal_width'], versicolor['sepal_width'], virginica['sepal_width']], bins=np.arange(2,5,.25), stacked=True)
plt.legend(['setosa', 'versicolor', 'virginica']);

# %%
virginica.count()
# Out:
# sepal_length    50
# sepal_width     50
# petal_length    50
# petal_width     50
# species         50
# dtype: int64

# %% [markdown]
# ## Bar Chart
#
# Bar charts are quite similar to line charts, i.e., they show a sequence of values. However, a bar is shown for each value, rather than points connected by lines. We can use the `plt.bar` function to draw a bar chart.

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, oranges)
plt.bar(years, apples)
plt.legend(['oranges', 'apples']);

# %% [markdown]
# Like histograms, we can stack bars on top of one another. We use the `bottom` argument of `plt.bar` to achieve this.

# %%
plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples)
plt.legend(['apples', 'oranges']);

# %% [markdown]
# ### Bar Plots with Averages
#
# Let's look at another sample dataset included with Seaborn, called `tips`. The dataset contains information about the sex, time of day, total bill, and tip amount for customers visiting a restaurant over a week.

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# We might want to draw a bar chart to visualize how the average bill amount varies across different days of the week. One way to do this would be to compute the day-wise averages and then use `plt.bar`

# %%
plt.title('Average bill amount on different days of the week')
plt.xlabel('day')
plt.ylabel('average bill amount')
plt.bar(tips_df['day'].unique(), tips_df.groupby(by=['day'])['total_bill'].mean());

# %% [markdown]
# Since this is a very common use case, the Seaborn library provides a `barplot` function which can automatically compute averages.

# %%
sns.barplot(x='day', y='total_bill', data=tips_df);

# %%
# Adding hue
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df);

# %%
# Changing the axis
sns.barplot(x='total_bill', y='day', hue='sex', data=tips_df);

# %% [markdown]
# #### pandas.DataFrame.pivot
# DataFrame.pivot(index=None, columns=None, values=None)[source]
# Return reshaped DataFrame organized by given index / column values.
#
# Reshape data (produce a “pivot” table) based on column values. Uses unique values from specified index / columns to form axes of the resulting DataFrame. This function does not support data aggregation, multiple values will result in a MultiIndex in the columns.

# %%
flight = sns.load_dataset('flights')
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
# Using pivot to reshape the output/table
flight_df = flight.pivot(index='month', columns='year', values='passengers')
flight_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %% [markdown]
# ## Heatmap
#
# A heatmap is used to visualize 2-dimensional data like a matrix or a table using colors. Let's visualize monthly passenger footfall at an airport over 12 years.

# %%
plt.title('No. of Passengers (1000s)')
sns.heatmap(flight_df);

# %% [markdown]
# `annot` option in sns.heatmap()
#
# Displays the actual values in each block by specifying `annot=True`.

# %%
plt.title('No. of Passengers (1000s)')
sns.heatmap(flight_df, annot=True);

# %% [markdown]
# the output is not clear, let's change the str format using `fmt` option.

# %%
plt.figure(figsize=(10,6))
plt.title('No. of Passengers (1000s)')
sns.heatmap(flight_df, annot=True, fmt='d');

# %% [markdown]
# Use the `cmap` argument to change the color palette.

# %%
plt.figure(figsize=(10,6))
plt.title('No. of passengers in 1000s')
sns.heatmap(flight_df, annot=True, fmt='d', cmap='Blues');

# %% [markdown]
# ### Pair plots with Seaborn
#
# Seaborn provides a helper function `sns.pairplot` to automatically plot several different charts for pairs of features within a dataframe.

# %%
flower_df = sns.load_dataset('iris')
sns.pairplot(flower_df, hue='species');

# %%
sns.pairplot(tips_df, hue='sex');
